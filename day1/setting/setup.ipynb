# %% [markdown]
# ## Basic Setups to use OpenAI Gym with Colab

# %%
# For colab monitor
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !apt-get update > /dev/null 2>&1
# !apt-get install cmake > /dev/null 2>&1
# !pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1
# Out:
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (58.2.0)

# %% [markdown]
# # 0. Connect google drive with Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/rl-hyundai/day1
# !ls
# Out:
# /content/drive/MyDrive/Colab Notebooks/rl-hyundai/day1
# Humanoid_expert.py	__pycache__  tabular_mdp    video
# HumanoidPyBulletEnv.py	setup.ipynb  torch_test.py

# %% [markdown]
# # 1. Introduction to Gym environment

# %% [markdown]
# ## 1.1 Prerequisites

# %%
import gym
from gym.wrappers import Monitor
import glob
import io
import base64
from IPython.display import HTML
from pyvirtualdisplay import Display
from IPython import display as ipythondisplay

display = Display(visible=0, size=(1400, 900))
display.start()

"""
Utility functions to enable video recording of gym environment 
and displaying it.
To enable video, just do "env = wrap_env(env)""
"""
def show_video():
    mp4list = glob.glob('video/*.mp4')
    if len(mp4list) > 0:
      mp4 = mp4list[0]
      video = io.open(mp4, 'r+b').read()
      encoded = base64.b64encode(video)
      ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                  loop controls style="height: 400px;">
                  <source src="data:video/mp4;base64,{0}" type="video/mp4" />
              </video>'''.format(encoded.decode('ascii'))))
    else: 
        print("Could not find video")
    

def wrap_env(env):
    env = Monitor(env, './video', force=True)
    return env

# %% [markdown]
# Now, we can render Gtm environment!

# %% [markdown]
# If you run in jupyter, turn
#
# ```
# colab = False
# ```

# %%
colab = True

# %% [markdown]
# ## 1.2 Basic environments

# %%
import gym

# TODO : Render classic control problems below
# CartPole-v1
# MountainCar-v0
# Pendulum-v0
# Visit https://gym.openai.com/envs/#classic_control for more environments!

env_id = 'Acrobot-v1'

# Build environment with env ID!
env = gym.make(env_id)
if colab:
    env = wrap_env(env)

# Initialize environment
observation = env.reset()

for t in range(1000):
    env.render()

    # Randomly sample action from environment
    action = env.action_space.sample() 
    
    # Simulate 1 step
    observation, reward, done, info = env.step(action) 
   
    # done is used to check terminal condition    
    if done: 
      break;

# Close environment
env.close()

# Render environment
if colab:
    show_video()
# Out:
# <video alt="test" autoplay
#                   loop controls style="height: 400px;">
#                   <source src="data:video/mp4;base64,..." type="video/mp4" />
#               </video>

# %%
# More complex problems
# !pip3 install box2d-py
# !pip3 install gym[Box_2D]
# Out:
# Requirement already satisfied: box2d-py in /usr/local/lib/python3.7/dist-packages (2.3.8)
# Requirement already satisfied: gym[Box_2D] in /usr/local/lib/python3.7/dist-packages (0.17.3)
# WARNING: gym 0.17.3 does not provide the extra 'box_2d'
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.4.1)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.19.5)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym[Box_2D]) (0.16.0)

# %%
import gym

# TODO : Render Box2d environments below
# BipedalWalker-v3
# LunarLander-v2
# CarRacing-v0
# Visit https://gym.openai.com/envs/#box2d for more environments!

env_id = 'CarRacing-v0'

# Build environment with env ID!
env = gym.make(env_id)
if colab:
    env = wrap_env(env)

# Initialize environment
observation = env.reset()

for t in range(1000):
    env.render()

    # Randomly sample action from environment
    action = env.action_space.sample() 
    
    # Simulate 1 step
    observation, reward, done, info = env.step(action) 
   
    # done is used to check terminal condition    
    if done: 
      break;

# Close environment
env.close()

# Render environment
if colab:
    show_video()
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Track generation: 1156..1449 -> 293-tiles track
# <video alt="test" autoplay
#                   loop controls style="height: 400px;">
#                   <source src="data:video/mp4;base64,..." type="video/mp4" />
#               </video>

# %% [markdown]
# ## 1.3 Atari environment

# %%
# Import atatri rom file included in colab
# !python -m atari_py.import_roms /content/drive/MyDrive/Colab\ Notebooks/rl-hyundai/ROMS
# Out:
# copying koolaid.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Kool-Aid Man (Kool Aid Pitcher Man) (1983) (M Network, Stephen Tatsumi, Jane Terjung - Kool Aid) (MT4648) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/koolaid.bin
# copying trondead.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/TRON - Deadly Discs (TRON Joystick) (1983) (M Network - INTV - APh Technological Consulting, Jeff Ronne, Brett Stutz) (MT5662) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/trondead.bin
# copying robotank.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Robot Tank (Robotank) (1983) (Activision, Alan Miller) (AZ-028, AG-028-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/robotank.bin
# copying hero.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/H.E.R.O. (1984) (Activision, John Van Ryzin) (AZ-036-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/hero.bin
# copying video_pinball.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Video Pinball - Arcade Pinball (1981) (Atari, Bob Smith - Sears) (CX2648 - 49-75161) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/video_pinball.bin
# copying amidar.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Amidar (1982) (Parker Brothers, Ed Temple) (PB5310) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/amidar.bin
# copying asteroids.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Asteroids (1981) (Atari, Brad Stewart - Sears) (CX2649 - 49-75163) [no copyright] ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/asteroids.bin
# copying beam_rider.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Beamrider (1984) (Activision - Cheshire Engineering, David Rolfe, Larry Zwick) (AZ-037-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/beam_rider.bin
# copying berzerk.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Berzerk (1982) (Atari, Dan Hitchens - Sears) (CX2650 - 49-75168) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/berzerk.bin
# copying bowling.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Bowling (1979) (Atari, Larry Kaplan - Sears) (CX2628 - 6-99842, 49-75117) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/bowling.bin
# copying centipede.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Centipede (1983) (Atari - GCC) (CX2676) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/centipede.bin
# copying crazy_climber.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Crazy Climber (1983) (Atari - Roklan, Joe Gaucher, Alex Leavens) (CX2683) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/crazy_climber.bin
# copying defender.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Defender (1982) (Atari, Robert C. Polaro, Alan J. Murphy - Sears) (CX2609 - 49-75186) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/defender.bin
# copying donkey_kong.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Donkey Kong (1987) (Atari) (CX26143).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/donkey_kong.bin
# copying frogger.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Frogger (1982) (Parker Brothers, Ed English, David Lamkins) (PB5300) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/frogger.bin
# copying name_this_game.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Name This Game (Guardians of Treasure) (1983) (U.S. Games Corporation - JWDA, Roger Booth, Sylvia Day, Ron Dubren, Todd Marshall, Robin McDaniel, Wes Trager, Henry Will IV) (VC1007) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/name_this_game.bin
# copying qbert.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Q-bert (1987) (Atari) (CX26150).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/qbert.bin
# copying surround.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Surround - Chase (Blockade) (1977) (Atari, Alan Miller - Sears) (CX2641 - 99807, 49-75105) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/surround.bin
# copying wizard_of_wor.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Wizard of Wor (1982) (CBS Electronics - Roklan, Joe Hellesen, Joe Wagner) (M8774, M8794) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/wizard_of_wor.bin
# copying venture.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Venture (1982) (Coleco, Joseph Biel) (2457) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/venture.bin
# copying tutankham.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Tutankham (1983) (Parker Brothers, Dave Engman, Dawn Stockbridge) (PB5340) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/tutankham.bin
# copying adventure.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Adventure (1980) (Atari, Warren Robinett) (CX2613, CX2613P) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/adventure.bin
# copying king_kong.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/King Kong (1982) (Tigervision - Software Electronics Corporation, Karl T. Olinger - Teldec) (7-001 - 3.60001 VE) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/king_kong.bin
# copying lost_luggage.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Lost Luggage (Airport Mayhem) (1982) (Apollo - Games by Apollo, Larry Minor, Ernie Runyon, Ed Salvo) (AP-2004) [no opening scene] ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/lost_luggage.bin
# copying riverraid.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/River Raid (1982) (Activision, Carol Shaw) (AX-020, AX-020-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/riverraid.bin
# copying road_runner.bin from patched version of /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Road Runner (1989) (Atari - Bobco, Robert C. Polaro) (CX2663) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/road_runner.bin
# copying up_n_down.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Up 'n Down (1984) (SEGA - Beck-Tech, Steve Beck, Phat Ho) (009-01) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/up_n_down.bin
# copying chopper_command.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Chopper Command (1982) (Activision, Bob Whitehead) (AX-015, AX-015-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/chopper_command.bin
# copying ice_hockey.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Ice Hockey - Le Hockey Sur Glace (1981) (Activision, Alan Miller) (AX-012, CAX-012, AX-012-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/ice_hockey.bin
# copying breakout.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Breakout - Breakaway IV (Paddle) (1978) (Atari, Brad Stewart - Sears) (CX2622 - 6-99813, 49-75107) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/breakout.bin
# copying boxing.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Boxing - La Boxe (1980) (Activision, Bob Whitehead) (AG-002, CAG-002, AG-002-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/boxing.bin
# copying freeway.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Freeway (1981) (Activision, David Crane) (AG-009, AG-009-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/freeway.bin
# copying demon_attack.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Demon Attack (Death from Above) (1982) (Imagic, Rob Fulop) (720000-200, 720101-1B, 720101-1C, IA3200, IA3200C, IX-006-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/demon_attack.bin
# copying asterix.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Asterix (AKA Taz) (07-27-1983) (Atari, Jerome Domurat, Steve Woita) (CX2696) (Prototype).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/asterix.bin
# copying sir_lancelot.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Sir Lancelot (1983) (Xonox - K-Tel Software - Product Guild, Anthony R. Henderson) (99006, 6220) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/sir_lancelot.bin
# copying seaquest.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Seaquest (1983) (Activision, Steve Cartwright) (AX-022) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/seaquest.bin
# copying phoenix.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Phoenix (1983) (Atari - GCC, Mike Feinstein, John Mracek) (CX2673) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/phoenix.bin
# copying alien.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Alien (1982) (20th Century Fox Video Games, Douglas 'Dallas North' Neubauer) (11006) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/alien.bin
# copying bank_heist.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Bank Heist (Bonnie & Clyde, Cops 'n' Robbers, Hold-Up, Roaring 20's) (1983) (20th Century Fox Video Games, Bill Aspromonte) (11012) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/bank_heist.bin
# copying journey_escape.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Journey Escape (1983) (Data Age, J. Ray Dettling) (112-006) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/journey_escape.bin
# copying frostbite.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Frostbite (1983) (Activision, Steve Cartwright) (AX-031) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/frostbite.bin
# copying elevator_action.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Elevator Action (1983) (Atari, Dan Hitchens) (CX26126) (Prototype) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/elevator_action.bin
# copying pooyan.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Pooyan (1983) (Konami) (RC 100-X 02) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/pooyan.bin
# copying solaris.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Solaris (The Last Starfighter, Star Raiders II, Universe) (1986) (Atari, Douglas Neubauer, Mimi Nyden) (CX26136) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/solaris.bin
# copying carnival.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Carnival (1982) (Coleco - Woodside Design Associates, Steve 'Jessica Stevens' Kitchen) (2468) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/carnival.bin
# copying montezuma_revenge.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Montezuma's Revenge - Featuring Panama Joe (1984) (Parker Brothers - JWDA, Henry Will IV) (PB5760) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/montezuma_revenge.bin
# copying zaxxon.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Zaxxon (1983) (Coleco) (2454) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/zaxxon.bin
# copying yars_revenge.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Yars' Revenge (Time Freeze) (1982) (Atari, Howard Scott Warshaw - Sears) (CX2655 - 49-75167) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/yars_revenge.bin
# copying star_gunner.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Stargunner (1983) (Telesys, Alex Leavens) (1005) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/star_gunner.bin
# copying pacman.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Pac-Man (1982) (Atari, Tod Frye) (CX2646) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/pacman.bin
# copying krull.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Krull (1983) (Atari, Jerome Domurat, Dave Staugas) (CX2682) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/krull.bin
# copying gopher.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Gopher (Gopher Attack) (1982) (U.S. Games Corporation - JWDA, Sylvia Day, Todd Marshall, Robin McDaniel, Henry Will IV) (VC2001) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/gopher.bin
# copying assault.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Assault (AKA Sky Alien) (1983) (Bomb - Onbase) (CA281).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/assault.bin
# copying enduro.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Enduro (1983) (Activision, Larry Miller) (AX-026, AX-026-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/enduro.bin
# copying kaboom.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Kaboom! (Paddle) (1981) (Activision, Larry Kaplan, David Crane) (AG-010, AG-010-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/kaboom.bin
# copying laser_gates.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Laser Gates (AKA Innerspace) (1983) (Imagic, Dan Oliver) (720118-2A, 13208, EIX-007-04I) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/laser_gates.bin
# copying pong.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Video Olympics - Pong Sports (Paddle) (1977) (Atari, Joe Decuir - Sears) (CX2621 - 99806, 6-99806, 49-75104) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/pong.bin
# copying fishing_derby.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Fishing Derby (1980) (Activision, David Crane) (AG-004) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/fishing_derby.bin
# copying skiing.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Skiing - Le Ski (1980) (Activision, Bob Whitehead) (AG-005, CAG-005, AG-005-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/skiing.bin
# copying galaxian.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Galaxian (1983) (Atari - GCC, Mark Ackerman, Tom Calderwood, Glenn Parker) (CX2684) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/galaxian.bin
# copying kung_fu_master.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Kung-Fu Master (1987) (Activision - Imagineering, Dan Kitchen, Garry Kitchen) (AG-039-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/kung_fu_master.bin
# copying pitfall.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Pitfall! - Pitfall Harry's Jungle Adventure (Jungle Runner) (1982) (Activision, David Crane) (AX-018, AX-018-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/pitfall.bin
# copying double_dunk.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Double Dunk (Super Basketball) (1989) (Atari, Matthew L. Hubbard) (CX26159) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/double_dunk.bin
# copying atlantis.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Atlantis (Lost City of Atlantis) (1982) (Imagic, Dennis Koble) (720103-1A, 720103-1B, IA3203, IX-010-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/atlantis.bin
# copying kangaroo.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Kangaroo (1983) (Atari - GCC, Kevin Osborn) (CX2689) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/kangaroo.bin
# copying air_raid.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Air Raid (Men-A-Vision) (PAL) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/air_raid.bin
# copying space_invaders.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Space Invaders (1980) (Atari, Richard Maurer - Sears) (CX2632 - 49-75153) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/space_invaders.bin
# copying keystone_kapers.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Keystone Kapers - Raueber und Gendarm (1983) (Activision, Garry Kitchen - Ariola) (EAX-025, EAX-025-04I - 711 025-725) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/keystone_kapers.bin
# copying tennis.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Tennis - Le Tennis (1981) (Activision, Alan Miller) (AG-007, CAG-007) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/tennis.bin
# copying time_pilot.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Time Pilot (1983) (Coleco - Woodside Design Associates, Harley H. Puthuff Jr.) (2663) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/time_pilot.bin
# copying private_eye.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Private Eye (1984) (Activision, Bob Whitehead) (AG-034-04) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/private_eye.bin
# copying jamesbond.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/James Bond 007 (James Bond Agent 007) (1984) (Parker Brothers - On-Time Software, Joe Gaucher, Louis Marbel) (PB5110) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/jamesbond.bin
# copying battle_zone.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Battlezone (1983) (Atari - GCC, Mike Feinstein, Brad Rice) (CX2681) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/battle_zone.bin
# copying mr_do.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Mr. Do! (1983) (CBS Electronics, Ed English) (4L4478) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/mr_do.bin
# copying ms_pacman.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Ms. Pac-Man (1983) (Atari - GCC, Mark Ackerman, Glenn Parker) (CX2675) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/ms_pacman.bin
# copying gravitar.bin from /content/drive/MyDrive/Colab Notebooks/rl-hyundai/ROMS/Gravitar (1983) (Atari, Dan Hitchens, Mimi Nyden) (CX2685) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/gravitar.bin

# %%
import gym

# TODO : Render below environments!
# Atlantis-ram-v0
# Breakout-ram-v0
# ...
# Visit https://gym.openai.com/envs/#atari for more environments!

env_id = 'Breakout-ram-v0'

# Build environment with env ID!
env = gym.make(env_id)
if colab:
    env = wrap_env(env)

# Initialize environment
observation = env.reset()

for t in range(1000):
    env.render()

    # Randomly sample action from environment
    action = env.action_space.sample() 
    
    # Simulate 1 step
    observation, reward, done, info = env.step(action) 
   
    # done is used to check terminal condition    
    if done: 
      break;

# Close environment
env.close()

# Render environment
if colab:
    show_video()
# Out:
# <video alt="test" autoplay
#                   loop controls style="height: 400px;">
#                   <source src="data:video/mp4;base64,..." type="video/mp4" />
#               </video>

# %% [markdown]
# ## 1.4 Robotics environment

# %%
# Install Robot simulator pybullet
# !pip install pybullet
# Out:
# Requirement already satisfied: pybullet in /usr/local/lib/python3.7/dist-packages (3.2.0)

# %%
import pybullet_envs

# TODO : Render below environments!
# HalfCheetahBulletEnv-v0
# HopperBulletEnv-v0
# HumanoidBulletEnv-v0
# Walker2DBulletEnv-v0

env_id = 'HumanoidBulletEnv-v0'

env = gym.make(env_id)
if colab:
    env = wrap_env(env)
observation = env.reset()

# Build environment with env ID!
env = gym.make(env_id)
if colab:
    env = wrap_env(env)

# Initialize environment
observation = env.reset()

for t in range(1000):
    env.render()

    # Randomly sample action from environment
    action = env.action_space.sample() 
    
    # Simulate 1 step
    observation, reward, done, info = env.step(action) 
   
    # done is used to check terminal condition    
    if done: 
      break;

# Close environment
env.close()

# Render environment
if colab:
    show_video()
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# <video alt="test" autoplay
#                   loop controls style="height: 400px;">
#                   <source src="data:video/mp4;base64,..." type="video/mp4" />
#               </video>

# %% [markdown]
# # 2. Run pretrained RL agent within Gym environment

# %%
import pybullet_envs
from Humanoid_expert import * # Pretrained model from https://github.com/benelot/pybullet-gym

env_id = 'HumanoidBulletEnv-v0'

env = gym.make(env_id)
if colab:
    env = wrap_env(env)
observation = env.reset()

# Build environment with env ID!
env = gym.make(env_id)
if colab:
    env = wrap_env(env)

# Initialize environment
observation = env.reset()

# Call trained policy!
pi = SmallReactivePolicy(env.observation_space, env.action_space)

for t in range(1000):
    env.render()

    # TODO : use policy pi to get action!
    # Hint : policy is mapping from state(observation) to action : pi(a|s)
    TODO = pi.act(TODO)
    
    # Simulate 1 step
    observation, reward, done, info = env.step(action) 
   
    # done is used to check terminal condition    
    if done: 
      break;

# Close environment
env.close()

# Render environment
if colab:
    show_video()
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# <video alt="test" autoplay
#                   loop controls style="height: 400px;">
#                   <source src="data:video/mp4;base64,..." type="video/mp4" />
#               </video>

# %% [markdown]
# #3. Torch gradient calculation test

# %%
import torch

x = torch.randn((5, 5), requires_grad=True)
y = torch.randn((5, 5), requires_grad=True)
z = torch.randn((5, 5), requires_grad=True)

v = (x + y) * z
w = torch.sum(v)

# w = (x + y) * z
w.backward()

# dw / dx  = z
print(z)
print(x.grad)
print('')

# dw / dz  = x + y
print(x+y)
print(z.grad)
# Out:
# tensor([[ 0.3269,  0.6287, -0.2850, -0.5911,  0.7632],
#         [ 0.1488, -1.4184, -0.2215,  0.5258, -0.1353],
#         [ 0.3123, -0.0696,  2.1284, -0.3167,  1.4689],
#         [-1.2023, -1.6358, -0.2142,  1.5430, -0.8675],
#         [ 1.2429, -0.0904,  1.7588, -1.4575, -0.6154]], requires_grad=True)
# tensor([[ 0.3269,  0.6287, -0.2850, -0.5911,  0.7632],
#         [ 0.1488, -1.4184, -0.2215,  0.5258, -0.1353],
#         [ 0.3123, -0.0696,  2.1284, -0.3167,  1.4689],
#         [-1.2023, -1.6358, -0.2142,  1.5430, -0.8675],
#         [ 1.2429, -0.0904,  1.7588, -1.4575, -0.6154]])
#
# tensor([[ 0.6599, -1.3759,  0.9103, -2.0321, -1.6221],
#         [-0.4255,  1.9292, -0.0686, -0.7171, -0.9385],
#         [-1.6371,  0.9145, -1.7995,  0.1375, -3.2374],
#         [ 1.5805,  0.8429,  1.2803,  0.0632,  0.4840],
#         [ 3.4218,  0.2130,  0.8353,  0.4022, -0.8132]], grad_fn=<AddBackward0>)
# tensor([[ 0.6599, -1.3759,  0.9103, -2.0321, -1.6221],
#         [-0.4255,  1.9292, -0.0686, -0.7171, -0.9385],
#         [-1.6371,  0.9145, -1.7995,  0.1375, -3.2374],
#         [ 1.5805,  0.8429,  1.2803,  0.0632,  0.4840],
#         [ 3.4218,  0.2130,  0.8353,  0.4022, -0.8132]])
